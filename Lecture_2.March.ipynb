# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
#         3.26633166,  3.31658291,  3.36683417,  3.41708543,  3.46733668,
#         3.51758794,  3.5678392 ,  3.61809045,  3.66834171,  3.71859296,
#         3.76884422,  3.81909548,  3.86934673,  3.91959799,  3.96984925,
#         4.0201005 ,  4.07035176,  4.12060302,  4.17085427,  4.22110553,
#         4.27135678,  4.32160804,  4.3718593 ,  4.42211055,  4.47236181,
#         4.52261307,  4.57286432,  4.62311558,  4.67336683,  4.72361809,
#         4.77386935,  4.8241206 ,  4.87437186,  4.92462312,  4.97487437,
#         5.02512563,  5.07537688,  5.12562814,  5.1758794 ,  5.22613065,
#         5.27638191,  5.32663317,  5.37688442,  5.42713568,  5.47738693,
#         5.52763819,  5.57788945,  5.6281407 ,  5.67839196,  5.72864322,
#         5.77889447,  5.82914573,  5.87939698,  5.92964824,  5.9798995 ,
#         6.03015075,  6.08040201,  6.13065327,  6.18090452,  6.23115578,
#         6.28140704,  6.33165829,  6.38190955,  6.4321608 ,  6.48241206,
#         6.53266332,  6.58291457,  6.63316583,  6.68341709,  6.73366834,
#         6.7839196 ,  6.83417085,  6.88442211,  6.93467337,  6.98492462,
#         7.03517588,  7.08542714,  7.13567839,  7.18592965,  7.2361809 ,
#         7.28643216,  7.33668342,  7.38693467,  7.43718593,  7.48743719,
#         7.53768844,  7.5879397 ,  7.63819095,  7.68844221,  7.73869347,
#         7.78894472,  7.83919598,  7.88944724,  7.93969849,  7.98994975,
#         8.04020101,  8.09045226,  8.14070352,  8.19095477,  8.24120603,
#         8.29145729,  8.34170854,  8.3919598 ,  8.44221106,  8.49246231,
#         8.54271357,  8.59296482,  8.64321608,  8.69346734,  8.74371859,
#         8.79396985,  8.84422111,  8.89447236,  8.94472362,  8.99497487,
#         9.04522613,  9.09547739,  9.14572864,  9.1959799 ,  9.24623116,
#         9.29648241,  9.34673367,  9.39698492,  9.44723618,  9.49748744,
#         9.54773869,  9.59798995,  9.64824121,  9.69849246,  9.74874372,
#         9.79899497,  9.84924623,  9.89949749,  9.94974874, 10.        ])

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
#        -0.12441577, -0.17409855, -0.22334179, -0.27202116, -0.32001378,
#        -0.36719847, -0.41345611, -0.45866992, -0.50272574, -0.54551235,
#        -0.58692173, -0.62684933, -0.66519435, -0.70185999, -0.73675367,
#        -0.7697873 , -0.80087747, -0.82994571, -0.85691862, -0.88172811,
#        -0.90431153, -0.92461187, -0.94257789, -0.95816422, -0.97133152,
#        -0.98204653, -0.99028221, -0.99601778, -0.99923873, -0.99993695,
#        -0.99811068, -0.99376451, -0.98690943, -0.97756275, -0.96574805,
#        -0.95149517, -0.93484009, -0.91582485, -0.89449748, -0.8709118 ,
#        -0.84512737, -0.81720929, -0.78722803, -0.75525929, -0.72138377,
#        -0.68568702, -0.64825913, -0.60919462, -0.56859209, -0.52655407,
#        -0.48318668, -0.4385994 , -0.39290482, -0.34621828, -0.29865766,
#        -0.25034303, -0.20139637, -0.15194126, -0.10210255, -0.05200606,
#        -0.00177827,  0.048454  ,  0.09856395,  0.14842506,  0.19791144,
#         0.24689816,  0.29526155,  0.34287951,  0.38963181,  0.43540043,
#         0.48006981,  0.52352718,  0.56566282,  0.60637036,  0.64554701,
#         0.68309389,  0.71891618,  0.75292346,  0.78502987,  0.81515434,
#         0.84322083,  0.86915847,  0.89290179,  0.91439084,  0.93357136,
#         0.95039493,  0.96481908,  0.9768074 ,  0.98632961,  0.99336168,
#         0.99788585,  0.99989069,  0.99937116,  0.99632856,  0.99077057,
#         0.98271122,  0.97217086,  0.95917611,  0.94375976,  0.92596075,
#         0.905824  ,  0.88340035,  0.85874643,  0.83192446,  0.80300216,
#         0.77205257,  0.7391538 ,  0.70438892,  0.66784571,  0.62961641,
#         0.58979754,  0.54848964,  0.50579699,  0.46182738,  0.41669181,
#         0.37050423,  0.32338126,  0.27544187,  0.22680707,  0.17759967,
#         0.12794389,  0.07796509,  0.02778946, -0.02245633, -0.07264543,
#        -0.12265112, -0.17234716, -0.22160808, -0.27030952, -0.31832851,
#        -0.36554384, -0.4118363 , -0.45708901, -0.50118772, -0.54402111])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('this is my X label')
plt.ylabel('this is my Y data')
plt.title('this is my title')
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 1000*np.random.rand(50)
colours = np.random.rand(50)
plt.scatter(x,y, c = colours, s = sizes, alpha = .5)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter')
plt.show()

# %%
x
# Out:
# array([0.62554357, 0.39737072, 0.2221848 , 0.32311393, 0.43105155,
#        0.65099259, 0.48834421, 0.56687404, 0.34336437, 0.29338454,
#        0.06393609, 0.39344034, 0.28484038, 0.17262246, 0.43291606,
#        0.99657118, 0.25949208, 0.76325209, 0.6033438 , 0.11390501,
#        0.52666619, 0.4193353 , 0.54886334, 0.86462689, 0.89911304,
#        0.12815512, 0.05022048, 0.35771028, 0.24509689, 0.17971027,
#        0.63953898, 0.33589572, 0.17314404, 0.85135235, 0.19798964,
#        0.54435212, 0.29934254, 0.02367184, 0.36522498, 0.18417707,
#        0.16234098, 0.36789985, 0.94565313, 0.47102703, 0.80093817,
#        0.35228309, 0.8645374 , 0.56280803, 0.29402553, 0.38468303])

# %%
y
# Out:
# array([0.0932988 , 0.79497624, 0.57774853, 0.37027145, 0.19960745,
#        0.70021644, 0.0093497 , 0.63194919, 0.40124485, 0.55810528,
#        0.72055973, 0.70357528, 0.96594869, 0.6495482 , 0.46167936,
#        0.51219302, 0.84775689, 0.1543584 , 0.32221458, 0.20065366,
#        0.75514319, 0.05773107, 0.34434626, 0.35407774, 0.4138602 ,
#        0.62906958, 0.97206529, 0.40290386, 0.46586706, 0.45642819,
#        0.1957943 , 0.18755885, 0.41819526, 0.90596527, 0.09999892,
#        0.53567105, 0.51334421, 0.30356411, 0.45628232, 0.91007488,
#        0.17516075, 0.21356151, 0.42507744, 0.34434341, 0.65228875,
#        0.05163475, 0.50294938, 0.24170133, 0.99747829, 0.6514141 ])

# %%
plt.plot(x,y)

# %%
plt.pie(x,y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4caa1eaec0>,
#   <matplotlib.patches.Wedge at 0x7f4caa1eb340>,
#   <matplotlib.patches.Wedge at 0x7f4caa1eb700>,
#   <matplotlib.patches.Wedge at 0x7f4caa1ebb80>,
#   <matplotlib.patches.Wedge at 0x7f4caa1ebe80>,
#   <matplotlib.patches.Wedge at 0x7f4caa220340>,
#   <matplotlib.patches.Wedge at 0x7f4caa2207f0>,
#   <matplotlib.patches.Wedge at 0x7f4caa220c70>,
#   <matplotlib.patches.Wedge at 0x7f4caa2210f0>,
#   <matplotlib.patches.Wedge at 0x7f4caa221570>,
#   <matplotlib.patches.Wedge at 0x7f4caa1eae90>,
#   <matplotlib.patches.Wedge at 0x7f4caa221e40>,
#   <matplotlib.patches.Wedge at 0x7f4caa2222c0>,
#   <matplotlib.patches.Wedge at 0x7f4caa222740>,
#   <matplotlib.patches.Wedge at 0x7f4caa222bc0>,
#   <matplotlib.patches.Wedge at 0x7f4caa223040>,
#   <matplotlib.patches.Wedge at 0x7f4caa2234c0>,
#   <matplotlib.patches.Wedge at 0x7f4caa223940>,
#   <matplotlib.patches.Wedge at 0x7f4caa223dc0>,
#   <matplotlib.patches.Wedge at 0x7f4caa260280>,
#   <matplotlib.patches.Wedge at 0x7f4caa260700>,
#   <matplotlib.patches.Wedge at 0x7f4caa260b80>,
#   <matplotlib.patches.Wedge at 0x7f4caa261000>,
#   <matplotlib.patches.Wedge at 0x7f4caa261480>,
#   <matplotlib.patches.Wedge at 0x7f4caa261900>,
#   <matplotlib.patches.Wedge at 0x7f4caa261d80>,
#   <matplotlib.patches.Wedge at 0x7f4caa262200>,
#   <matplotlib.patches.Wedge at 0x7f4caa262680>,
#   <matplotlib.patches.Wedge at 0x7f4caa262b00>,
#   <matplotlib.patches.Wedge at 0x7f4caa262f80>,
#   <matplotlib.patches.Wedge at 0x7f4caa263400>,
#   <matplotlib.patches.Wedge at 0x7f4caa263880>,
#   <matplotlib.patches.Wedge at 0x7f4caa263d00>,
#   <matplotlib.patches.Wedge at 0x7f4caa2981c0>,
#   <matplotlib.patches.Wedge at 0x7f4caa298640>,
#   <matplotlib.patches.Wedge at 0x7f4caa298ac0>,
#   <matplotlib.patches.Wedge at 0x7f4caa298f40>,
#   <matplotlib.patches.Wedge at 0x7f4caa2993c0>,
#   <matplotlib.patches.Wedge at 0x7f4caa299840>,
#   <matplotlib.patches.Wedge at 0x7f4caa299cc0>,
#   <matplotlib.patches.Wedge at 0x7f4caa29a140>,
#   <matplotlib.patches.Wedge at 0x7f4caa29a5c0>,
#   <matplotlib.patches.Wedge at 0x7f4caa29aa40>,
#   <matplotlib.patches.Wedge at 0x7f4caa29afb0>,
#   <matplotlib.patches.Wedge at 0x7f4caa29b370>,
#   <matplotlib.patches.Wedge at 0x7f4caa29b7f0>,
#   <matplotlib.patches.Wedge at 0x7f4caa29bc70>,
#   <matplotlib.patches.Wedge at 0x7f4caa0dc130>,
#   <matplotlib.patches.Wedge at 0x7f4caa0dc5b0>,
#   <matplotlib.patches.Wedge at 0x7f4caa0dca30>],
#  [Text(1.1883020103531285, 0.1090887525894292, ''),
#   Text(1.8401002778018347, 0.4527316058030397, ''),
#   Text(1.5861776603999802, 0.5466996875067619, ''),
#   Text(1.3474088035637397, 0.5883771227117599, ''),
#   Text(1.1264754203434637, 0.6480992538267969, ''),
#   Text(1.3993037965561723, 1.132575878026469, ''),
#   Text(0.7345039852806172, 0.8313607179494386, ''),
#   Text(0.9334413528349755, 1.4588815027874098, ''),
#   Text(0.633981770578223, 1.3608097637023437, ''),
#   Text(0.557331733418031, 1.5616319812590451, ''),
#   Text(0.5214789843303367, 1.7442756051261683, ''),
#   Text(0.39987946855938045, 1.7586870669584054, ''),
#   Text(0.2561557236271313, 2.0500068848575266, ''),
#   Text(0.10030183008850505, 1.746670671866136, ''),
#   Text(-0.04880448901674963, 1.560916570943552, ''),
#   Text(-0.3839360805812717, 1.5658095074777176, ''),
#   Text(-0.8018141988126023, 1.7750636348764215, ''),
#   Text(-0.6810574070799882, 1.0533640384352507, ''),
#   Text(-0.9940736964983663, 1.0171095323252148, ''),
#   Text(-1.0015613348524957, 0.8298040904309074, ''),
#   Text(-1.533060990797356, 1.0446436088706843, ''),
#   Text(-1.0375434122138782, 0.5136583514975093, ''),
#   Text(-1.3719280975597594, 0.45160757487097514, ''),
#   Text(-1.4451053564888086, 0.16128418762336483, ''),
#   Text(-1.4975401190729525, -0.22168966518408256, ''),
#   Text(-1.6532144588651456, -0.5065210524122126, ''),
#   Text(-1.964644164893277, -0.6585042751108783, ''),
#   Text(-1.393954246225685, -0.5617931778161854, ''),
#   Text(-1.3951355411595543, -0.7110108729898339, ''),
#   Text(-1.3401390012778962, -0.7915151175762941, ''),
#   Text(-1.0288975025556015, -0.7876882693544357, ''),
#   Text(-0.900609990228591, -0.9201681583351757, ''),
#   Text(-0.9782353448420766, -1.1610221574428738, ''),
#   Text(-1.0488866106565418, -1.7098928454826665, ''),
#   Text(-0.46361162471238254, -1.1068250393674632, ''),
#   Text(-0.46462779373860347, -1.5682923163560076, ''),
#   Text(-0.26428610280157017, -1.5915503165122664, ''),
#   Text(-0.1642363311247943, -1.393922037902598, ''),
#   Text(-0.09389428289981255, -1.5534472998264586, ''),
#   Text(0.04026622707556232, -2.00967153348022, ''),
#   Text(0.09013597900130713, -1.2719710852736408, ''),
#   Text(0.1941443509853038, -1.2991350286878345, ''),
#   Text(0.5094221120305648, -1.4374805459203586, ''),
#   Text(0.7523540128811738, -1.2329198327472528, ''),
#   Text(1.1738242269494066, -1.3010198039833671, ''),
#   Text(0.904119455291787, -0.7133236390039734, ''),
#   Text(1.414408119507456, -0.7542522103200008, ''),
#   Text(1.2890715786031801, -0.3720980204200323, ''),
#   Text(2.0721305507703986, -0.32510025672363174, ''),
#   Text(1.748639398423312, -0.0985474325915354, '')])

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
x = ['a','b','c','d','e']

# %%
y = np.random.rand(5)
plt.bar(x,y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Bar Diagram')
plt.show()

# %%
plt.bar(x,y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Bar Diagram')
plt.show()

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y,'--g')
plt.xlabel('this is my X label')
plt.ylabel('this is my Y data')
plt.title('this is my title')
plt.grid()
plt.show()

# %%
plt.figure(figsize = (6,4))
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 1000*np.random.rand(50)
colours = np.random.rand(50)
plt.scatter(x,y, c = 'r', s = sizes, alpha = .5,marker = 'x')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter')
plt.grid()
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [6,7,8,9,10,11]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,8,19,16,13]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,8,19,16,13]
plt.scatter(x,y)
plt.show()

# %%
data = [1,2,3,4,4,4,4,5,6,7,8,9]

# %%
plt.hist(data)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,8,19,16,13]
colors = ['red','blue','#800080','#FFA500','#FF0000','#A52A2A']
plt.scatter(x,y, c = colors)
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
plt.show()
